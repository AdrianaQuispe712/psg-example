# %%
print ("Hola, Mundo desde Notebook!")
# Out:
# Hola, Mundo desde Notebook!

# %%
print("   *   ")
print("  ***  ")
print(" ***** ")
print("   |   ")
# Out:
#    *
#   ***
#  *****
#    |

# %% [markdown]
# # Sesión 04
# - Mi primer notebook
# - Imprimir árbol
# - Crear Markdown
# - Subir a mi repositorio de GitHub
#
# ## 🌲
